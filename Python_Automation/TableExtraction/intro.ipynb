# %%
import pandas as pd

# %%
#Extracting tables from websites
stats=pd.read_html("https://en.wikipedia.org/wiki/Suresh_Raina")
stats[1]
# Out:
#              Competition   Test    ODI   T20I     FC
# 0                Matches     18    226     78    109
# 1            Runs scored    768   5615   1605   6871
# 2        Batting average  26.48  35.31  29.18  42.15
# 3               100s/50s    1/7   5/36    1/5  14/45
# 4              Top score    120   116*    101   204*
# 5           Balls bowled   1041   2126    349   3457
# 6                Wickets     13     36     13     41
# 7        Bowling average  46.38  50.30  34.00  41.97
# 8   5 wickets in innings      0      0      0      0
# 9    10 wickets in match      0      0      0      0
# 10          Best bowling    2/1   3/34    2/6   3/31
# 11     Catches/stumpings   23/–  102/–   42/–  118/–

# %%
#Extracting tables from .csv files
csv=pd.read_csv("https://stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2021-financial-year-provisional/Download-data/annual-enterprise-survey-2021-financial-year-provisional-csv.csv")
csv.rename(columns={'Industry_aggregation_NZSIOC':'Col1','Industry_code_NZSIOC':'Col 3'},inplace=True)
csv
# Out:
#        Year     Col1  Col 3        Industry_name_NZSIOC               Units  \
# 0      2021  Level 1  99999              All industries  Dollars (millions)
# 1      2021  Level 1  99999              All industries  Dollars (millions)
# 2      2021  Level 1  99999              All industries  Dollars (millions)
# 3      2021  Level 1  99999              All industries  Dollars (millions)
# 4      2021  Level 1  99999              All industries  Dollars (millions)
# ...     ...      ...    ...                         ...                 ...
# 41710  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41711  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41712  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41713  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 41714  2013  Level 3   ZZ11  Food product manufacturing          Percentage
#
# ...

# %%
#Extracting tables from .pdf files using camelot-py library
import camelot as cam
table =cam.read_pdf('foo.pdf',pages="1")
table
# Out:
# <TableList n=1>

# %%
table.export('abc.csv',f='csv',compress=True)
table[0]
table[0].parsing_report
# Out:
# {'accuracy': 99.02, 'whitespace': 12.24, 'order': 1, 'page': 1}

# %%
table[0].to_csv('abc.csv')
table[0].df
# Out:
#               0            1                2                     3  \
# 0  Cycle \nName  KI \n(1/km)  Distance \n(mi)  Percent Fuel Savings
# 1                                                  Improved \nSpeed
# 2        2012_2         3.30              1.3                  5.9%
# 3        2145_1         0.68             11.2                  2.4%
# 4        4234_1         0.59             58.7                  8.5%
# 5        2032_2         0.17             57.8                 21.7%
# 6        4171_1         0.07            173.9                 58.1%
#
#                    4                  5                 6
# 0
# 1  Decreased \nAccel  Eliminate \nStops  Decreased \nIdle
# 2               9.5%              29.2%             17.4%
# 3               0.1%               9.5%              2.7%
# 4               1.3%               8.5%              3.3%
# 5               0.3%               2.7%              1.2%
# 6               1.6%               2.1%              0.5%
